# %%
import pandas as pd

car = pd.read_csv('../data/external/caractéristiques.csv', sep=';')
val = pd.read_csv('../data/external/valeurs_mensuelles.csv', sep=';')

val.head(20)
car.head(20)
# Out:
#        idBank               Dernière mise à jour  \
# 0   010768717                   06/05/2026 08:45
# 1         NaN                                NaN
# 2       Codes                                NaN
# 3         NaN                                NaN
# 4           Q  Couvert par le secret statistique
# 5           E                         Estimation
# 6           F                          Prévision
# 7           P                         Provisoire
# 8          SD             Valeur semi-définitive
# 9           R                           Révision
# 10          A                     Valeur normale
# 11          N           Valeur non significative
# 12          O                   Valeur manquante
# 13          U                    Valeur atypique
#
#                      Autres regroupements IDBANK pour sdmx  Puissance  Nature  \
# 0   NACE - 41 - Construction de bâtiments          BDM_EUR        0.0  Indice
# ...
